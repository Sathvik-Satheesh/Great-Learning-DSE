# %% [markdown]
# # <center>PGP Data Science Engineering</center>
# ## <center>Introduction to Programming – Mini Project:</center>

# %% [markdown]
# ### Problem 1:
#
# 1. Write a program to calculate area of shapes. Your program should be capable of calculating the area of a square, rectangle, triangle and a circle. The user should be presented with options to select the shape. Based on which shape is chosed by the user, the program should ask for the appropriate input and print the resulting area on the screen.
#
# When the program is run, the screen should display something like this:
#
# **Which shape would you like to calculate the area for? Please enter the option number-**<br>
# **1. Square**<br>
# **2. Rectangle**<br>
# **3. Triangle**<br>
# **4. Circle**<br>
# **Enter Option: _**
#
# Say the user enters the option 1.
#
# **Please enter the length of a side: _**
#
# If the user enters a value of 5. The output should be:
#
# **The area of the square is 25**
#
# This program should indicate that the input is invalid if the user enters a character instead of a number as input. For instance if the user enters a value of ‘a’ instead of 5 in the previous example the program should prompt:
#
# **Invalid input, please enter a number: _**

# %%
def square():
    length = input("Please enter the length of a side: ")
    if length.isalpha() == True:
        length = int(input("Invalid input, please enter a number: "))
        areasq = length*length
    else: 
        leng = int(length)
        areasq = leng*leng
    print("The area of the square is ", areasq)
def rectangle():
    length = input("Please enter the length: ")
    if length.isalpha() == True:
        length1 = float(input("Invalid input, please enter a number: "))
    else:
        length1 = float(length)
    breadth = input("Please enter the breadth: ")
    if breadth.isalpha() == True:
        breadth1 = float(input("Invalid input, please enter a number: "))
    else:
        breadth1 = float(breadth)
    arearec = length1*breadth1
    print("The area of the rectangle is ", arearec)
def triangle():
    base = input("Please enter the length of base: ")
    if base.isalpha() == True:
        base1 = float(input("Invalid input, please enter a number: "))
    else:
        base1 = float(base)
    height = input("Please enter the breadth: ")
    if height.isalpha() == True:
        height1 = float(input("Invalid input, please enter a number: "))
    else:
        height1 = float(breadth)
    areatri = (1/2)*base1*height1
    print("The area of the triangle is ", areatri)
def circle():
    radius = (input("Please enter the radius of the circle: "))
    if radius.isalpha() == True:
        radius1 = float(input("Invalid input, please enter a number: "))
    else:
        radius1 = float(radius)
    areacir = (22/7)*(radius1**2)
    print("The area of the circle is ", areacir)
      
def selector():
    if sh == 1:
        square()
    elif sh == 2:
        rectangle()
    elif sh == 3:
        triangle()
    elif sh == 4:
        circle()

shape = input("Which shape would you like to calculate the are for? Please enter the option number-\n 1. Square\n 2. Rectangle\n 3. Triangle\n 4. Circle\nEnter Option: ")
if shape.isalpha() == True:
    sh = int(input("Invalid input, please enter a number: "))
    selector()
else:
    sh = int(shape)
    selector()
# Out:
# Which shape would you like to calculate the are for? Please enter the option number-
#  1. Square
#  2. Rectangle
#  3. Triangle
#  4. Circle
# Enter Option: d
# Invalid input, please enter a number: 2
# Please enter the length: a
# Invalid input, please enter a number: 5
# Please enter the breadth: b
# Invalid input, please enter a number: 13
# The area of the rectangle is  65.0

# %% [markdown]
# ### Problem 2:
#
# Create and encrypter in python based on the ceaser cipher. It is a substitution cipher where each character of the original text is shifted a certain number characters in the alphabet. Write a function that would require 2 arguments – the input text to be encrypted and a key. For eg: Given the input text ‘hello’ and the key 3, the resulting encryted text would be ‘khoor’. Here you can see that every character in the string hello is shifted by 3 characters. ‘h’ has shifted to ‘k’, ‘e’ has shifted to ‘h’ and so on. If a key of 5 were used, the resulting string would be ‘mjqqt’. This function should be capable of ignoring any characters which are not alphabets. Th2 character ‘z’ entered b
# y the user for a key of 3 would result in ‘c’.
#
# Usage:<br>
# **encrypt(‘hello world!’, 3)**<br>
# **‘khoor zruog!’**
#
# Similarly create decrypter which can decode the encryted text when provided the input text and key
#
# Usage:<br>
# **decrypt(‘khoor zruog!’, 3)**<br>
# **‘hello world!’**
#
# For the sake of simplicity you can assume that input solely consists of lowercase alphabets, spaces and punctuation symbols. Numbers in the input text would also be ignored similar to symbols.

# %%
def decrypt(mystr2,b):

    mylist3 = []

    mylist1 = list(mystr2)

    for i in mylist1:
        if i==' ':
            z = mylist3.append(i)
            continue
        y = ord(i)-b
        if y > ord('z'):
            y = y + 26
        y = chr(y)
    
        z = mylist3.append(y)
    
    d = ''.join(mylist3)

    print("The decrypted result is '%s!'"%d)

def encrypt(mystr1,a):

    mylist2 = []

    mylist = list(mystr1)

    for i in mylist:
        if i==' ':
            z = mylist2.append(i)
            continue
        x = ord(i)+a
        if x > ord('z'):
            x = x - 26
        x = chr(x)
    
        z = mylist2.append(x)
    
    c = ''.join(mylist2)

    print("The encrypted result is '%s!'"%c)
encrypt('hello world',3)
decrypt('khoor zruog',3)
# Out:
# The encrypted result is 'khoor zruog!'
# The decrypted result is 'hello world!'
